# %%
from pathlib import Path


ROOT = Path("C:/Users/lindo/Downloads/ALPR-RU")


DATASET = ROOT / "dataset"

TEST_IMAGES = DATASET / "test" / "images"

TRAIN_IMAGES = DATASET / "train" / "images"

VALID_IMAGES = DATASET / "valid" / "images"

APP_FOLDER = ROOT / "app"

HISTORY_FOLDER = APP_FOLDER / "history"

HISTORY_FOLDER.mkdir(exist_ok=True)

HISTORY_JSON = HISTORY_FOLDER / "history.json"


UPLOAD_FOLDER = APP_FOLDER / "uploads"

UPLOAD_FOLDER.mkdir(exist_ok=True)

OCR_LANG = ["en"]


YOLO_MODELS = {

    "YOLOv5":
        ROOT / "models" / "yolov5_best.pt",

    "YOLOv8":
        ROOT / "models" /  "yolov8_best.pt",

    "YOLOv10":
        ROOT / "models" / "yolov10_best.pt",

}

RESULT_FILES = {

    "YOLOv5":
        ROOT / "results_yolov5.csv",

    "YOLOv8":
        ROOT / "results_yolov8.csv",

    "YOLOv10":
        ROOT / "results_yolov10.csv",

}



YOLOS_JSON = ROOT / "yolos_predictions.json"

DETR_JSON = ROOT / "detr_predictions.json"

APP_TITLE = "ALPR-RU"

APP_ICON = "🚗"
